# %%
#importing libraries 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import warnings
warnings.filterwarnings('ignore') #for not showing warnings messages

# %%
#loading data
df = pd.read_csv("C:/Users/10-Me22/Downloads/Mall_Customers.csv")

# %%
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %% [markdown]
# # Univariate Analysis

# %%
df.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
sns.distplot(df['Annual Income (k$)']); #showing density of Annual Income

# %%
df.columns
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
#showing density for important columns
columns = ['Age', 'Annual Income (k$)','Spending Score (1-100)']
for i in columns:
    plt.figure() #for showing each one in its figure
    sns.distplot(df[i])

# %%
sns.kdeplot(df['Annual Income (k$)'],shade=True)
# Out:
# <Axes: xlabel='Annual Income (k$)', ylabel='Density'>

# %%
columns = ['Age', 'Annual Income (k$)','Spending Score (1-100)']
for i in columns:
    plt.figure()
    sns.kdeplot(df[i],shade=True)

# %%
columns = ['Age', 'Annual Income (k$)','Spending Score (1-100)']
for i in columns:
    plt.figure()
    sns.boxplot(data=df,x='Gender',y=df[i])

# %%
df['Gender'].value_counts(normalize=True) #normalize=True to show  it as percentage
# Out:
# Female    0.56
# Male      0.44
# Name: Gender, dtype: float64

# %% [markdown]
# # Bivariate Analysis

# %%
sns.scatterplot(data=df, x='Annual Income (k$)',y='Spending Score (1-100)' )
# Out:
# <Axes: xlabel='Annual Income (k$)', ylabel='Spending Score (1-100)'>

# %%
df=df.drop('CustomerID',axis=1) #we dropped CustomerID cuz it does not affect our dataset
sns.pairplot(df,hue='Gender')

# %%
df.groupby(['Gender'])['Age', 'Annual Income (k$)',
       'Spending Score (1-100)'].mean()
#we see that mean in both male and female is very close
# Out:
#               Age  Annual Income (k$)  Spending Score (1-100)
# Gender
# Female  38.098214           59.250000               51.526786
# Male    39.806818           62.227273               48.511364

# %%
df.corr()
# Out:
#                              Age  Annual Income (k$)  Spending Score (1-100)
# Age                     1.000000           -0.012398               -0.327227
# Annual Income (k$)     -0.012398            1.000000                0.009903
# Spending Score (1-100) -0.327227            0.009903                1.000000

# %%
sns.heatmap(df.corr(),annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# # Clustering - Univariate, Bivariate, Multivariate

# %%
intertia_scores=[]
for i in range(1,11):
    kmeans=KMeans(n_clusters=i)
    kmeans.fit(df[['Annual Income (k$)']])
    intertia_scores.append(kmeans.inertia_)
    
intertia_scores
# Out:
# [137277.28000000003,
#  48660.88888888889,
#  23517.330930930926,
#  13278.112713472487,
#  8481.496190476191,
#  5050.904761904763,
#  3949.2756132756135,
#  2822.4996947496943,
#  2253.4464052287585,
#  1801.9043956043956]

# %%
plt.plot(range(1,11),intertia_scores)

# %%
clustering1 = KMeans(n_clusters=4)

# %%
clustering1.fit(df[['Annual Income (k$)']])
# Out:
# KMeans(n_clusters=4)

# %%
df['Income Cluster'] = clustering1.labels_
df.head()
# Out:
#    Gender  Age  Annual Income (k$)  Spending Score (1-100)  Income Cluster
# 0    Male   19                  15                      39               2
# 1    Male   21                  15                      81               2
# 2  Female   20                  16                       6               2
# 3  Female   23                  16                      77               2
# 4  Female   31                  17                      40               2

# %%
df['Income Cluster'].value_counts()
# Out:
# 0    68
# 1    62
# 2    50
# 3    20
# Name: Income Cluster, dtype: int64

# %%
clustering1.inertia_
# Out:
# 13278.112713472487

# %%
df.columns
# Out:
# Index(['Gender', 'Age', 'Annual Income (k$)', 'Spending Score (1-100)',
#        'Income Cluster'],
#       dtype='object')

# %%
df.groupby('Income Cluster')['Age', 'Annual Income (k$)',
       'Spending Score (1-100)'].mean()
# Out:
#                       Age  Annual Income (k$)  Spending Score (1-100)
# Income Cluster
# 0               43.970588           54.764706               50.014706
# 1               36.838710           77.806452               50.403226
# 2               35.280000           27.400000               49.480000
# 3               36.600000          109.700000               52.000000

# %% [markdown]
# # Bivariate Clustering

# %%
intertia_scores2=[]
for i in range(1,11):
    kmeans2=KMeans(n_clusters=i)
    kmeans2.fit(df[['Annual Income (k$)','Spending Score (1-100)']])
    intertia_scores2.append(kmeans2.inertia_)
plt.plot(range(1,11),intertia_scores2)

# %%
clustering2 = KMeans(n_clusters=5)
clustering2.fit(df[['Annual Income (k$)','Spending Score (1-100)']])
df['Spending and Income Cluster'] =clustering2.labels_
df.head()
# Out:
#    Gender  Age  Annual Income (k$)  Spending Score (1-100)  Income Cluster  \
# 0    Male   19                  15                      39               2
# 1    Male   21                  15                      81               2
# 2  Female   20                  16                       6               2
# 3  Female   23                  16                      77               2
# 4  Female   31                  17                      40               2
#
#    Spending and Income Cluster
# 0                            1
# 1                            3
# 2                            1
# 3                            3
# 4                            1

# %%
#getting centers of x, y to show in our graph
centers =pd.DataFrame(clustering2.cluster_centers_)
centers.columns = ['x','y']

# %%
plt.figure(figsize=(10,8))
plt.scatter(x=centers['x'],y=centers['y'],s=100,c='black',marker='*')
sns.scatterplot(data=df, x ='Annual Income (k$)',y='Spending Score (1-100)',hue='Spending and Income Cluster',palette='tab10')
plt.savefig('clustering_bivaraiate.png') #to save the plot so we can use it in our report

# %%
pd.crosstab(df['Spending and Income Cluster'],df['Gender'],normalize='index')
# Out:
# Gender                         Female      Male
# Spending and Income Cluster
# 0                            0.592593  0.407407
# 1                            0.608696  0.391304
# 2                            0.538462  0.461538
# 3                            0.590909  0.409091
# 4                            0.457143  0.542857

# %%
df.groupby('Spending and Income Cluster')['Age', 'Annual Income (k$)',
       'Spending Score (1-100)'].mean()
# Out:
#                                    Age  Annual Income (k$)  \
# Spending and Income Cluster
# 0                            42.716049           55.296296
# 1                            45.217391           26.304348
# 2                            32.692308           86.538462
# 3                            25.272727           25.727273
# 4                            41.114286           88.200000
#
#                              Spending Score (1-100)
# Spending and Income Cluster
# 0                                         49.518519
# 1                                         20.913043
# 2                                         82.128205
# 3                                         79.363636
# 4                                         17.114286

# %% [markdown]
# # Mulivariate clustering

# %%
#multivariate needs to deal with only numeric data
from sklearn.preprocessing import StandardScaler

# %%
scale = StandardScaler()

# %%
df.head()
# Out:
#    Gender  Age  Annual Income (k$)  Spending Score (1-100)  Income Cluster  \
# 0    Male   19                  15                      39               2
# 1    Male   21                  15                      81               2
# 2  Female   20                  16                       6               2
# 3  Female   23                  16                      77               2
# 4  Female   31                  17                      40               2
#
#    Spending and Income Cluster
# 0                            1
# 1                            3
# 2                            1
# 3                            3
# 4                            1

# %%
dff = pd.get_dummies(df,drop_first=True) #get_dummies to convert string in gender column into integr & drop_first=True to drop column os Gender_Female cuz we need one ccolumn to represent gender whether it is male or female 1 equal true and 0 equal false
dff.head()
# Out:
#    Age  Annual Income (k$)  Spending Score (1-100)  Income Cluster  \
# 0   19                  15                      39               2
# 1   21                  15                      81               2
# 2   20                  16                       6               2
# 3   23                  16                      77               2
# 4   31                  17                      40               2
#
#    Spending and Income Cluster  Gender_Male
# 0                            1            1
# 1                            3            1
# 2                            1            0
# 3                            3            0
# 4                            1            0

# %%
dff.columns
# Out:
# Index(['Age', 'Annual Income (k$)', 'Spending Score (1-100)', 'Income Cluster',
#        'Spending and Income Cluster', 'Gender_Male'],
#       dtype='object')

# %%
dff = dff[['Age', 'Annual Income (k$)', 'Spending Score (1-100)','Gender_Male']] #set column into what we need and delete others
dff.head()
# Out:
#    Age  Annual Income (k$)  Spending Score (1-100)  Gender_Male
# 0   19                  15                      39            1
# 1   21                  15                      81            1
# 2   20                  16                       6            0
# 3   23                  16                      77            0
# 4   31                  17                      40            0

# %%
dff = scale.fit_transform(dff)

# %%
dff = pd.DataFrame(scale.fit_transform(dff))
dff.head()
# Out:
#           0         1         2         3
# 0 -1.424569 -1.738999 -0.434801  1.128152
# 1 -1.281035 -1.738999  1.195704  1.128152
# 2 -1.352802 -1.700830 -1.715913 -0.886405
# 3 -1.137502 -1.700830  1.040418 -0.886405
# 4 -0.563369 -1.662660 -0.395980 -0.886405

# %%
intertia_scores3=[]
for i in range(1,11):
    kmeans3=KMeans(n_clusters=i)
    kmeans3.fit(dff)
    intertia_scores3.append(kmeans3.inertia_)
plt.plot(range(1,11),intertia_scores3)

# %%
df
# Out:
#      Gender  Age  Annual Income (k$)  Spending Score (1-100)  Income Cluster  \
# 0      Male   19                  15                      39               2
# 1      Male   21                  15                      81               2
# 2    Female   20                  16                       6               2
# 3    Female   23                  16                      77               2
# 4    Female   31                  17                      40               2
# ..      ...  ...                 ...                     ...             ...
# 195  Female   35                 120                      79               3
# 196  Female   45                 126                      28               3
# 197    Male   32                 126                      74               3
# 198    Male   32                 137                      18               3
# 199    Male   30                 137                      83               3
#
#      Spending and Income Cluster
# ...

# %%
df.to_csv('Clustering.csv')
